# %%
# Import Tweeter APIs
import tweepy as tp
import GetOldTweets3 as got

# Import libraries for data reading
import pandas as pd

import yaml

# %%
#Twitter API access token and consumer key with their authentication code read from a yaml file.
# Keep the secret keys private and not public
with open(r"secret.yml") as file:
    secret_list = yaml.load(file, Loader=yaml.FullLoader)
    
#Access the Twitter API
auth = tp.OAuthHandler(secret_list["consumer_key"], secret_list["consumer_secret"])
auth.set_access_token(secret_list["access_token"], secret_list["access_secret"])
api = tp.API(auth, wait_on_rate_limit=True)

# %%
tweet_query = "@AIRTEL_KE"
count = 200000

# %%
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(tweet_query)\
                                            .setMaxTweets(count)
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
tweets_lst = [[tw.id, tw.date, tw.text, tw.username, tw.retweets, tw.favorites, tw.geo, tw.mentions, tw.hashtags] for tw in tweets]

# %%
# Confirm that we received the number of tweets requested
len(tweets_lst)
# Out:
# 200000

# %%
tweets_df = pd.DataFrame(tweets_lst, columns=["ID", "Date", "Post", "Username","Retweets", "Favorites", "Geo", "Mentions", "Hashtags"])
tweets_df.sample(10)
# Out:
#                          ID                      Date  \
# 196456  1172500452279312384 2019-09-13 13:21:06+00:00
# 133289  1213554154733326336 2020-01-04 20:13:51+00:00
# 196798  1172406622439661568 2019-09-13 07:08:15+00:00
# 63377   1264079869564137472 2020-05-23 06:25:01+00:00
# 29359   1281690207692218368 2020-07-10 20:42:12+00:00
# 84015   1252965374561153026 2020-04-22 14:19:58+00:00
# 11007   1290118726507884544 2020-08-03 02:54:08+00:00
# 138645  1209474157840404480 2019-12-24 14:01:24+00:00
# 10090   1290566277526937600 2020-08-04 08:32:32+00:00
# 33503   1294543754511020033 2020-08-15 07:57:37+00:00
#
#                                                      Post         Username  \
# 196456         Do one for iPhone 11, im so ready to play.     williamasiga
# 133289  Hi Pambo. We have Huawei E5330MiFi 5,499/= tha...        AIRTEL_KE
# 196798  Sorry for the delay, airtime was credited ^Car...        AIRTEL_KE
# 63377                          @AIRTEL_KE kindly check DM  AbdulrazzaqSal5
# 29359   Guys this guys jokes can cure corona delete de...  MYWORLD39185437
# 84015   @airtelindia @AIRTEL_KE @Airtel_Presence @Airt...    Wilsonpselvam
# 11007   Whats the progress. So that I know what to do ...           simwa_
# 138645   @AIRTEL_KE your unlimited bundles are pure scam           Dekitdk
# 10090   Please download on a. Android for Play store- ...        AIRTEL_KE
# 33503   JLCPCB Prototype For $2/5pcs, 24 Hours Quick T...           JLCPCB
#
#         Retweets  Favorites Geo  \
# 196456         0          0
# 133289         0          1
# 196798         0          0
# 63377          0          0
# 29359          0          0
# 84015          0          0
# 11007          0          0
# 138645         0          0
# 10090          0          0
# 33503         33        259
#
#                                                  Mentions Hashtags
# 196456
# 133289
# 196798                                           @Pesapal
# 63377                                          @AIRTEL_KE
# 29359
# 84015   @airtelindia @AIRTEL_KE @Airtel_Presence @Airt...
# 11007
# 138645                                         @AIRTEL_KE
# 10090
# 33503

# %%
airtel_mention_df = tweets_df[tweets_df["Mentions"].str.contains("@AIRTEL_KE") | tweets_df["Mentions"].str.contains("@airtel_ke")]
print(airtel_mention_df.shape)
airtel_mention_df.to_csv(path_or_buf="AirtelMentions.csv")
airtel_mention_df.sample(20)
# Out:
# (47380, 9)
#                          ID                      Date  \
# 63884   1263800746803449856 2020-05-22 11:55:52+00:00
# 109101  1234815839771254785 2020-03-03 12:20:12+00:00
# 155503  1201757354146095104 2019-12-03 06:57:35+00:00
# 184490  1181551502093164544 2019-10-08 12:46:44+00:00
# 128835  1217015177591369728 2020-01-14 09:26:44+00:00
# 119505  1225517843464237065 2020-02-06 20:33:17+00:00
# 92337   1247260046867791872 2020-04-06 20:29:02+00:00
# 180010  1184404928434978816 2019-10-16 09:45:14+00:00
# 29542   1281606117735436288 2020-07-10 15:08:04+00:00
# 69186   1260954378464374786 2020-05-14 15:25:25+00:00
# 79118   1255135832836431877 2020-04-28 14:04:36+00:00
# 59254   1265931997966368768 2020-05-28 09:04:42+00:00
# 46523   1272848146964586498 2020-06-16 11:07:01+00:00
# 79038   1255181217160400898 2020-04-28 17:04:56+00:00
# 6215    1292162008385822721 2020-08-08 18:13:24+00:00
# 3820    1293444781927014402 2020-08-12 07:10:41+00:00
# 60936   1264985475141505025 2020-05-25 18:23:34+00:00
# 6390    1292096763831226373 2020-08-08 13:54:09+00:00
# 199218  1170237912191029249 2019-09-07 07:30:34+00:00
# 40645   1276191291454472197 2020-06-25 16:31:29+00:00
#
#                                                      Post         Username  \
# 63884   @AIRTEL_KE whats up!! today your network has b...     GitauVictor1
# 109101  Osa ìtambya ùmunthì!! Thamììa nthìnì wa mùtand...          MusyiFM
# 155503             Thank you @AIRTEL_KE I got my free 1Gb       MUTEMBEI1D
# 184490  @AIRTEL_KE so today you just decided to change...  reubenmuriithi3
# 128835  @AIRTEL_KE and when I check my balance it says...         Wamucii_
# 119505  @AIRTEL_KE I was FOREVER FRUSTRATED by their s...         A_Njambi
# 92337   @AIRTEL_KE please it's very impossible in a pe...  Wainaina_shakes
# 180010  @AIRTEL_KE is it true that we cannot make Airt...        Willoukom
# 29542   @AIRTEL_KE So now you guys have started taking...           GMunga
# 69186   @AIRTEL_KE Hello Airtel Customer care, this li...      AliceMercy7
# 79118                                @AIRTEL_KE jaymo??!        its_noobie
# 59254   @AIRTEL_KE just close shop and go home! How ca...     DanielzMaina
# 46523            @AIRTEL_KE what is it with your network?      MistaWahome
# 79038   @AIRTEL_KE sort my 3g data browsing Network he...   Antony23832972
# 6215    @AIRTEL_KE Your OTP takes forever to receive f...     RajuShah0707
# 3820    @AIRTEL_KE why is internet acting up? Since ye...       is_you_mee
# 60936   @AIRTEL_KE number yenu NI gani ...I need to ta...        022finest
# 6390    @AIRTEL_KE please help OH76FGBU6S Confirmed. K...  Jeffersonmchar3
# 199218  @AIRTEL_KE Your expenditure for Kshs 20 worth ...           _tymme
# 40645   @AIRTEL_KE right now I'm in the house at Boya ...       vikogilloh
#
#         Retweets  Favorites Geo                 Mentions         Hashtags
# 63884          0          0                   @AIRTEL_KE
# 109101         0          1                   @AIRTEL_KE  #SwitchToAirtel
# 155503         0          0                   @AIRTEL_KE
# 184490         0          0                   @AIRTEL_KE
# 128835         0          0                   @AIRTEL_KE
# 119505         0          0                   @AIRTEL_KE
# 92337          0          0                   @AIRTEL_KE
# 180010         0          1                   @AIRTEL_KE
# 29542          0          0                   @AIRTEL_KE
# 69186          0          0                   @AIRTEL_KE
# 79118          0          1                   @AIRTEL_KE
# 59254          0          0                   @AIRTEL_KE
# 46523          0          0                   @AIRTEL_KE
# 79038          0          0      @AIRTEL_KE @TelkomKenya
# 6215           0          0                   @AIRTEL_KE
# 3820           0          0                   @AIRTEL_KE
# 60936          0          0                   @AIRTEL_KE
# 6390           0          0                   @AIRTEL_KE
# 199218         0          0                   @AIRTEL_KE
# 40645          0          0                   @AIRTEL_KE

# %%
airtel_mention_df = pd.read_csv("AirtelMentions.csv")
airtel_mention_df.drop(columns=['Unnamed: 0'], inplace=True)
airtel_mention_df.sample(20)
# Out:
#                         ID                       Date  \
# 42811  1184464411924357121  2019-10-16 13:41:36+00:00
# 31339  1218886657035984899  2020-01-19 13:23:19+00:00
# 21401  1245641963463774209  2020-04-02 09:19:21+00:00
# 20225  1248485534210510849  2020-04-10 05:38:41+00:00
# 28141  1229645590054744064  2020-02-18 05:55:29+00:00
# 35961  1204664130688425984  2019-12-11 07:28:04+00:00
# 32802  1213756511819837440  2020-01-05 09:37:57+00:00
# 40799  1189482731090132992  2019-10-30 10:02:37+00:00
# 30137  1222806392538648577  2020-01-30 08:58:57+00:00
# 11673  1270067760807268360  2020-06-08 18:58:45+00:00
# 25819  1236280599037476865  2020-03-07 13:20:38+00:00
# 33369  1211859919093293056  2019-12-31 04:01:34+00:00
# 30147  1222800337410707457  2020-01-30 08:34:53+00:00
# 1431   1292139715186110464  2020-08-08 16:44:49+00:00
# 33763  1210430431063089152  2019-12-27 05:21:18+00:00
# 9399   1276555530308370433  2020-06-26 16:38:50+00:00
# 28615  1227835651242037248  2020-02-13 06:03:25+00:00
# 14647  1263343956483506182  2020-05-21 05:40:45+00:00
# 5964   1282753736830582784  2020-07-13 19:08:17+00:00
# 40996  1188758104755855360  2019-10-28 10:03:12+00:00
#
#                                                     Post         Username  \
# 42811    @AIRTEL_KE what is happening with your network?    bwire_gabriel
# 31339  @AIRTEL_KE You say its a smartphone network ye...         _teeray_
# 21401                                         @AIRTEL_KE  NaomiWa26182390
# 20225  @AIRTEL_KE Good morning, kindly respond to my ...        Colmakoko
# 28141  @AIRTEL_KE I'm a very frustrated customer. I'v...     FaithSimiyu_
# 35961  As in kununua bundle tu ndio inaniletea shida ...        laureezyF
# 32802  @AIRTEL_KE I need help topping up my line whil...          Njehia_
# 40799  @SafaricomPLC1 ,@Safaricom_Care ,@AIRTEL_KE @F...        OmryErler
# 30137  @AIRTEL_KE is the way Son. 20 bob gets twitter...   IamZakariaNoor
# 11673  Very true, Mombasa 4G ni jina tu inadecorate s...       masiresamu
# 25819     @AIRTEL_KE am not getting my air money balance   JacksonndunguH
# 33369             @AIRTEL_KE your free watsap is a scam       IamHillary_
# 30147  @AIRTEL_KE Hi am having a problem accessing my...      kipropkatwa
# 1431                         @AIRTEL_KE mmeresolve issue          muchxyz
# 33763  Me: Aki mi nakupenda Her: Uko sure unanipenda ...     WanjikuVoice
# 9399         @AIRTEL_KE please check your DM and advice.       abukhamsa1
# 28615  @AIRTEL_KE I bought airtime worth 2,000 on 27t...       muthonimil
# 14647  @AIRTEL_KE do you usually sell a wifi gadgets ...  moracha_richard
# 5964   @AIRTEL_KE Hi,your bundles are not working. 07...       FredMsembi
# 40996                                        @AIRTEL_KE     Evans69094574
#
#        Retweets  Favorites  Geo  \
# 42811         0          0  NaN
# 31339         0          0  NaN
# 21401         0          0  NaN
# 20225         0          0  NaN
# 28141         0          0  NaN
# 35961         0          1  NaN
# 32802         0          0  NaN
# 40799         0          1  NaN
# 30137         0          0  NaN
# 11673         0          1  NaN
# 25819         0          0  NaN
# 33369         0          0  NaN
# 30147         1          0  NaN
# 1431          0          1  NaN
# 33763         0          0  NaN
# 9399          0          0  NaN
# 28615         0          0  NaN
# 14647         0          0  NaN
# 5964          0          0  NaN
# 40996         0          0  NaN
#
#                                                 Mentions  \
# 42811                                         @AIRTEL_KE
# 31339                                         @AIRTEL_KE
# 21401                                         @AIRTEL_KE
# 20225                                         @AIRTEL_KE
# 28141                                         @AIRTEL_KE
# 35961                                         @AIRTEL_KE
# 32802                                         @AIRTEL_KE
# 40799  @SafaricomPLC1 @Safaricom_Care @AIRTEL_KE @Fau...
# 30137                                         @AIRTEL_KE
# 11673                                         @AIRTEL_KE
# 25819                                         @AIRTEL_KE
# 33369                                         @AIRTEL_KE
# 30147                                         @AIRTEL_KE
# 1431                                          @AIRTEL_KE
# 33763                                         @AIRTEL_KE
# 9399                                          @AIRTEL_KE
# 28615                                         @AIRTEL_KE
# 14647                                         @AIRTEL_KE
# 5964                                          @AIRTEL_KE
# 40996                                         @AIRTEL_KE
#
#                               Hashtags
# 42811                              NaN
# 31339                              NaN
# 21401                              NaN
# 20225                              NaN
# 28141                              NaN
# 35961                              NaN
# 32802                              NaN
# 40799                              NaN
# 30137                              NaN
# 11673                              NaN
# 25819                              NaN
# 33369                              NaN
# 30147                              NaN
# 1431                               NaN
# 33763  #BeSureNaAirtel #besurenaairtel
# 9399                               NaN
# 28615                              NaN
# 14647                              NaN
# 5964                               NaN
# 40996                              NaN

# %%
# airtel_replies=[]
# for x, Id in enumerate(airtel_mention_df["ID"]):
#     tweet_id = Id
#     name = airtel_mention_df.Username.iloc[x]
#     replies = []
#     print(x)
#     for tweet in tp.Cursor(api.search,q='to:'+name, since_id = tweet_id, timeout=999999).items():

#         if hasattr(tweet, 'in_reply_to_status_id_str'):
#             if (tweet.in_reply_to_status_id_str==tweet_id):
#                 replies.append(tweet)
#             for tweet in replies:
#                 row = {'ID':tweet_id, 'Date': airtel_mention_df.Date.iloc[x], 'Username':name, 
#                         'Post': airtel_mention_df.Post.iloc[x],  'Replier': tweet.user.screen_name, 
#                         'Mentions': airtel_mention_df.Mentions.iloc[x],  'Hashtags': airtel_mention_df.Hashtags.iloc[x],  
#                         'Reply_date':tweet.created_at, 'Reply': tweet.text.replace('\n', ' '), 
#                         'Reply_mentions':' '.join(x['screen_name'] for x in tweet.entities['user_mentions']), 
#                         'Reply_Hashtags':' '.join(x['text'] for x in tweet.entities['hashtags'])}
#                 airtel_replies.append(row)

# %%
def retriver(name, tweet_id,tweetsData):
    try:
        tweet_data = tp.Cursor(api.user_timeline,id='AIRTEL_KE', since_id = tweet_id, timeout=999999).items()
    except:
        print('failed to get data')
        tweet_data = []
    for tweet in tweet_data:
        if tweet not in tweetsData:
            tweetsData.append(tweet)
    
    return tweetsData

# %%
# Data_tweets=[]
# ts = retriver('ntvkenya', '1294919890839773184', Data_tweets)
# ts[0].id

# %%
def get_replies(Data_tweets,df, tweet_id):
    airtel_replies=[]
    replies = []
    for tweet in Data_tweets:
#         print('In list')
        if hasattr(tweet, 'in_reply_to_status_id_str'):
            if (tweet.in_reply_to_status_id_str==tweet_id):
                replies.append(tweet)
                print('good to go ID')
    if len(replies) > 0:
        for tweet in replies:
            print('good to go')
            row = {'ID':tweet_id, 'Date': df.Date.iloc[x], 'Username':name, 
                    'Post': df.Post.iloc[x],  'Replier': tweet.user.screen_name, 
                    'Mentions': df.Mentions.iloc[x],  'Hashtags': df.Hashtags.iloc[x],  
                    'Reply_date':tweet.created_at, 'Reply': tweet.text.replace('\n', ' '), 
                    'Reply_mentions':' '.join(x['screen_name'] for x in tweet.entities['user_mentions']), 
                    'Reply_Hashtags':' '.join(x['text'] for x in tweet.entities['hashtags'])}
            airtel_replies.append(row)
    return airtel_replies

# %%
repliesData = []
sort_df = airtel_mention_df.sort_values(by = 'ID')
Data_tweets=[]

# %%
for x, Id in enumerate(sort_df["ID"]):
    tweet_id = Id
    name = sort_df.Username.iloc[x]
    print(x)
    present = False
    print(len(Data_tweets))
    for tw in Data_tweets:
        if tw.in_reply_to_status_id_str == tweet_id:
            present = True
    print(present)
    if present == True:
        print('good')
        try:
            repliesData.extend(get_replies(Data_tweets, sort_df, tweet_id))
        except:
            print('failed')
    else:
        try:
            Data_tweets= retriver(name, tweet_id, Data_tweets)
            print("Run retriver")
            repliesData.extend(get_replies(Data_tweets, sort_df, tweet_id))
        except:
            print('failed')
            
    airtelData_df = pd.DataFrame(repliesData)

    airtelData_df.to_csv(path_or_buf="AirtelData.csv")
# Out:
# 0
# 0
# False
# Run retriver
# 1
# 3247
# False
# Run retriver
# 2
# 3247
# False
# Run retriver
# 3
# 3247
# False
# Run retriver
# 4
# 3256
# False

# %%
airtelData_df = pd.DataFrame(repliesData)

airtelData_df.to_csv(path_or_buf="AirtelData.csv")

# %%
airtelData_df.sample(20)

# %%
# test = api.get_status('1243081255102615552')
# test.entities

# %%
tC = got.manager.TweetCriteria().setUsername("barackobama").setSince("2015-09-10")\
                                            .setMaxTweets(1)
twts = got.manager.TweetManager.getTweets(tC)
for twe in twts:
    for tw in twe:
        print(tw)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-acf48d1e2396> in <module>
#       3 twts = got.manager.TweetManager.getTweets(tC)
#       4 for twe in twts:
# ----> 5     for tw in twe:
#       6         print(tw)
#
# TypeError: 'Tweet' object is not iterable

# %%
print(sort_df.ID.head(1))
print(sort_df.ID.tail(1))
# Out:
# 199993    1169605566479687680
# Name: ID, dtype: object
# 3    1295448699070554119
# Name: ID, dtype: object

# %%
api.get_status('1169605566479687680')
# Out:
# Status(_api=<tweepy.api.API object at 0x0000022441941B00>, _json={'created_at': 'Thu Sep 05 13:37:51 +0000 2019', 'id': 1169605566479687680, 'id_str': '1169605566479687680', 'text': 'Please clarify this because I have visited your shop in Narok and they are saying the lines are not working… https://t.co/PNmw0GfW7G', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/PNmw0GfW7G', 'expanded_url': 'https://twitter.com/i/web/status/1169605566479687680', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [109, 132]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3026331367, 'id_str': '3026331367', 'name': 'Ronoh K Clinton 🇰🇪', 'screen_name': 'RonohClinton', 'location': 'Kenya', 'description': 'Digital Marketer, Entrepreneur, For Business inquiries contact 0100423808\nEmail: ronohkclinton@gmail.com', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 58797, 'friends_count': 32562, 'listed_count': 17, 'created_at': 'Wed Feb 18 15:20:20 +0000 2015', 'favourites_count': 755, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7647, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1293999269339332608/0ka6uIL-_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1293999269339332608/0ka6uIL-_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3026331367/1596098969', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1168494581559615488, 'quoted_status_id_str': '1168494581559615488', 'quoted_status': {'created_at': 'Mon Sep 02 12:03:12 +0000 2019', 'id': 1168494581559615488, 'id_str': '1168494581559615488', 'text': 'Have you been counted among those with the new Airtel number series?\nVisit any Airtel shop to customize a prepaid o… https://t.co/FEHHeki6sI', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/FEHHeki6sI', 'expanded_url': 'https://twitter.com/i/web/status/1168494581559615488', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://www.socialbakers.com/" rel="nofollow">Socialbakers</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 191765987, 'id_str': '191765987', 'name': 'Airtel Kenya', 'screen_name': 'AIRTEL_KE', 'location': 'Kenya', 'description': 'Get in touch. Speak from the heart. Seal the deal.\n\nLike us on Facebook: \nhttps://t.co/IUx81e4dMP  \n\nPhone: *100#', 'url': 'https://t.co/uBs8x5assX', 'entities': {'url': {'urls': [{'url': 'https://t.co/uBs8x5assX', 'expanded_url': 'https://www.airtelkenya.com/', 'display_url': 'airtelkenya.com', 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/IUx81e4dMP', 'expanded_url': 'https://www.facebook.com/AirtelKe', 'd ...

# %%
1295448699070554119 - 1169605566479687680
# Out:
# 125843132590866439

# %%
# This is the code I need you to run on a strong and faster machine without any internet fluctuation

status_id_lst = airtel_mention_df["ID"].tolist()
dataAirtel = []

for x in range(1169605566479687680, 1295448699070554119):
    tweet = api.get_status(str(x))
    if tweet.in_reply_to_status_id_str in status_id_lst:
        df = airtel_mention_df.loc[airtel_mention_df['ID'] == tweet.in_reply_to_status_id_str]
        for rw in df.values.tolist():
            row = {'ID':rw[0], 'Date': rw[1], 'Username':rw[3], 
                    'Post': rw[2], 'Mentions': rw[7],  'Hashtags': rw[8],
                    'Replier': tweet.user.screen_name,  
                    'Reply_date':tweet.created_at, 'Reply': tweet.text.replace('\n', ' '), 
                    'Reply_mentions':' '.join(x['screen_name'] for x in tweet.entities['user_mentions']), 
                    'Reply_Hashtags':' '.join(x['text'] for x in tweet.entities['hashtags'])}
            dataAirtel.append(row)
